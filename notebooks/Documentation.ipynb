# %%
import json
from chp_client import get_client

# %%
client = get_client()

# %%
preds = client.predicates()
print(json.dumps(preds, indent=2))
# Out:
# {
#   "biolink:Gene": {
#     "biolink:Disease": [
#       "biolink:gene_associated_with_condition"
#     ],
#     "biolink:Drug": [
#       "biolink:interacts_with"
#     ]
#   },
#   "biolink:Drug": {
#     "biolink:Disease": [
#       "biolink:treats"
#     ],
#     "biolink:Gene": [
#       "biolink:interacts_with"
#     ]
#   },
#   "biolink:Disease": {
#     "biolink:PhenotypicFeature": [
#       "biolink:has_phenotype"
#     ]
#   }
# }

# %%
curies = client.curies()
curies_sub = dict()
for curie_type, curie_dict in curies.items():
    curies_sub[curie_type] = dict()
    for curie_id, names in list(curie_dict.items())[:5]:
        curies_sub[curie_type][curie_id] = names
print(json.dumps(curies_sub, indent=2))
# Out:
# {
#   "biolink:Gene": {
#     "ENSEMBL:ENSG00000106665": [
#       "CLIP2"
#     ],
#     "ENSEMBL:ENSG00000241973": [
#       "PI4KA"
#     ],
#     "ENSEMBL:ENSG00000143126": [
#       "CELSR2"
#     ],
#     "ENSEMBL:ENSG00000115641": [
#       "FHL2"
#     ],
#     "ENSEMBL:ENSG00000110042": [
#       "DTX4"
#     ]
#   },
#   "biolink:Drug": {
#     "CHEMBL:CHEMBL1201247": [
#       "ZOLADEX",
#       "GOSERELIN"
#     ],
#     "CHEMBL:CHEMBL88": [
#       "CYCLOPHOSPHAMIDE",
#       "CYTOXAN"
#     ],
#     "CHEMBL:CHEMBL53463": [
#       "DOXORUBICIN",
#       "ADRIAMYCIN"
#     ],
#     "CHEMBL:CHEMBL1201585": [
#       "HERCEPTIN",
#       "TRASTUZUMAB"
#     ],
#     "CHEMBL:CHEMBL1351": [
#       "CARBOPLATIN"
#     ]
#   },
#   "biolink:PhenotypicFeature": {
#     "EFO:0008007": [
#       "age_of_assessment",
#       "age_of_diagnosis"
#     ],
#     "EFO:0000714": [
#       "survival_time"
#     ],
#     "PATO:0000047": [
#       "sex",
#       "gender"
#     ],
#     "NCIT:C158992": [
#       "path_t",
#       "pathologic_t",
#       "ajcc_pathologic_t"
#     ],
#     "NCIT:C158989": [
#       "path_m",
#       "pathologic_m",
#       "ajcc_pathologic_m"
#     ]
#   }
# }

# %%
versions = client.versions()
print(json.dumps(versions, indent=2))
# Out:
# {
#   "chp": "2.3.1",
#   "chp_client": "1.1.3",
#   "chp_data": "1.0.2",
#   "pybkb": "2.0.0"
# }

# %%
from chp_client.query import build_standard_query, build_wildcard_query, build_onehop_query
# Out:
# WARNING:ToolkitGenerator:Range of slot 'treated by' (treatment) does not line with the domain of its inverse (treats)
# WARNING:ToolkitGenerator:Range of slot 'approved for treatment by' (treatment) does not line with the domain of its inverse (approved to treat)
# WARNING:ToolkitGenerator:Prefix case mismatch - supplied: NCBIGene expected: NCBIGENE
# WARNING:ToolkitGenerator:Prefix case mismatch - supplied: NCBIGene expected: NCBIGENE
# WARNING:trapi_model.biolink.constants:Could not get element for microRNA.
# WARNING:trapi_model.biolink.constants:Could not get element for siRNA.
# WARNING:trapi_model.biolink.constants:Could not get element for created_with.

# %%
q = build_standard_query(
                genes=['ENSEMBL:ENSG00000121879'],
                drugs=['CHEMBL:CHEMBL88'],
                disease='MONDO:0007254',
                outcome='EFO:0000714',
                outcome_name='survival_time',
                outcome_op='>',
                outcome_value=700,
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
    print("Probability of survival greater than 700 days:",client.get_outcome_prob(response))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": [
#             "ENSEMBL:ENSG00000121879"
#           ],
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         },
#         "n2": {
#           "ids": [
#             "CHEMBL:CHEMBL88"
#           ],
#           "categories": [
#             "biolink:Drug"
#           ],
#           "constraints": []
#         },
#         "n3": {
#           "ids": [
#             "EFO:0000714"
#           ],
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n1",
#           "object": "n0",
#           "constraints": []
#         },
#         "e1": {
#           "predicates": [
#             "biolink:treats"
#           ],
#           "relation": null,
#           "subject": "n2",
#           "object": "n0",
#           "constraints": []
#         },
#         "e2": {
#           "predicates": [
#             "biolink:has_phenotype"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n3",
#           "constraints": [
#             {
#               "name": "survival_time",
#               "id": "EFO:0000714",
#               "operator": ">",
#               "value": 700,
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             }
#           ]
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000121879": {
#           "name": "PIK3CA",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL88": {
#           "name": "CYCLOPHOSPHAMIDE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "EFO:0000714": {
#           "name": "EFO:0000714",
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e1": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e2": {
#           "predicate": "biolink:has_phenotype",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "EFO:0000714",
#           "attributes": [
#             {
#               "attribute_type_id": "Probability of Survival",
#               "original_attribute_name": null,
#               "value": 0.6562500000000003,
#               "value_type_id": "biolink:has_confidence_level",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e2"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n3": [
#             {
#               "id": "EFO:0000714"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "a4d1bd48-cd7a-4116-83be-d4e9a35655e1"
# }
# Probability of survival greater than 700 days: 0.6562500000000003

# %%
q = build_standard_query(
                disease='MONDO:0007254',
                outcome='EFO:0000714',
                outcome_name='survival_time',
                outcome_op='>',
                outcome_value=700,
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
    print("Probability of survival greater than 700 days:",client.get_outcome_prob(response))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": [
#             "EFO:0000714"
#           ],
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:has_phenotype"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n1",
#           "constraints": [
#             {
#               "name": "survival_time",
#               "id": "EFO:0000714",
#               "operator": ">",
#               "value": 700,
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             }
#           ]
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:has_phenotype",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Probability of Survival",
#               "original_attribute_name": null,
#               "value": 0.33080808080807816,
#               "value_type_id": "biolink:has_confidence_level",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "94286daa-4791-43cd-bec8-97533929e28c"
# }
# Probability of survival greater than 700 days: 0.33080808080807816

# %%
q = build_standard_query(
                genes=['ENSEMBL:ENSG00000121879'],
                drugs=['CHEMBL:CHEMBL88'],
                disease='MONDO:0007254',
                outcome='EFO:0000714',
                outcome_name='survival_time',
                outcome_op='>',
                outcome_value=1000,
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
    print("Probability of survival greater than 700 days:",client.get_outcome_prob(response))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": [
#             "ENSEMBL:ENSG00000121879"
#           ],
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         },
#         "n2": {
#           "ids": [
#             "CHEMBL:CHEMBL88"
#           ],
#           "categories": [
#             "biolink:Drug"
#           ],
#           "constraints": []
#         },
#         "n3": {
#           "ids": [
#             "EFO:0000714"
#           ],
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n1",
#           "object": "n0",
#           "constraints": []
#         },
#         "e1": {
#           "predicates": [
#             "biolink:treats"
#           ],
#           "relation": null,
#           "subject": "n2",
#           "object": "n0",
#           "constraints": []
#         },
#         "e2": {
#           "predicates": [
#             "biolink:has_phenotype"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n3",
#           "constraints": [
#             {
#               "name": "survival_time",
#               "id": "EFO:0000714",
#               "operator": ">",
#               "value": 1000,
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             }
#           ]
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000121879": {
#           "name": "PIK3CA",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL88": {
#           "name": "CYCLOPHOSPHAMIDE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "EFO:0000714": {
#           "name": "EFO:0000714",
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e1": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e2": {
#           "predicate": "biolink:has_phenotype",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "EFO:0000714",
#           "attributes": [
#             {
#               "attribute_type_id": "Probability of Survival",
#               "original_attribute_name": null,
#               "value": 0.5625000000000002,
#               "value_type_id": "biolink:has_confidence_level",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e2"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n3": [
#             {
#               "id": "EFO:0000714"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "a5480f4c-0095-4095-92dd-2c80601d7c77"
# }
# Probability of survival greater than 700 days: 0.5625000000000002

# %%
q = build_standard_query(
                genes=['ENSEMBL:ENSG00000121879', 'ENSEMBL:ENSG00000141510', 'ENSEMBL:ENSG00000196557', 'ENSEMBL:ENSG00000132155'],
                drugs=['CHEMBL:CHEMBL88'],
                disease='MONDO:0007254',
                outcome='EFO:0000714',
                outcome_name='survival_time',
                outcome_op='>',
                outcome_value=700,
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
    print("Probability of survival greater than 700 days:",client.get_outcome_prob(response))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": [
#             "ENSEMBL:ENSG00000121879"
#           ],
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         },
#         "n2": {
#           "ids": [
#             "ENSEMBL:ENSG00000141510"
#           ],
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         },
#         "n3": {
#           "ids": [
#             "ENSEMBL:ENSG00000196557"
#           ],
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         },
#         "n4": {
#           "ids": [
#             "ENSEMBL:ENSG00000132155"
#           ],
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         },
#         "n5": {
#           "ids": [
#             "CHEMBL:CHEMBL88"
#           ],
#           "categories": [
#             "biolink:Drug"
#           ],
#           "constraints": []
#         },
#         "n6": {
#           "ids": [
#             "EFO:0000714"
#           ],
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n1",
#           "object": "n0",
#           "constraints": []
#         },
#         "e1": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n2",
#           "object": "n0",
#           "constraints": []
#         },
#         "e2": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n3",
#           "object": "n0",
#           "constraints": []
#         },
#         "e3": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n4",
#           "object": "n0",
#           "constraints": []
#         },
#         "e4": {
#           "predicates": [
#             "biolink:treats"
#           ],
#           "relation": null,
#           "subject": "n5",
#           "object": "n0",
#           "constraints": []
#         },
#         "e5": {
#           "predicates": [
#             "biolink:has_phenotype"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n6",
#           "constraints": [
#             {
#               "name": "survival_time",
#               "id": "EFO:0000714",
#               "operator": ">",
#               "value": 700,
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             }
#           ]
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000121879": {
#           "name": "PIK3CA",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000141510": {
#           "name": "TP53",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000196557": {
#           "name": "CACNA1H",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000132155": {
#           "name": "RAF1",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL88": {
#           "name": "CYCLOPHOSPHAMIDE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "EFO:0000714": {
#           "name": "EFO:0000714",
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e1": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000141510",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e2": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000196557",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e3": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000132155",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e4": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e5": {
#           "predicate": "biolink:has_phenotype",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "EFO:0000714",
#           "attributes": [
#             {
#               "attribute_type_id": "Probability of Survival",
#               "original_attribute_name": null,
#               "value": 0.8705038362336379,
#               "value_type_id": "biolink:has_confidence_level",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e2"
#             }
#           ],
#           "e3": [
#             {
#               "id": "e3"
#             }
#           ],
#           "e4": [
#             {
#               "id": "e4"
#             }
#           ],
#           "e5": [
#             {
#               "id": "e5"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "ENSEMBL:ENSG00000141510"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000196557"
#             }
#           ],
#           "n4": [
#             {
#               "id": "ENSEMBL:ENSG00000132155"
#             }
#           ],
#           "n5": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n6": [
#             {
#               "id": "EFO:0000714"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "9dffe916-65d1-4fba-9225-a12a84477354"
# }
# Probability of survival greater than 700 days: 0.8705038362336379

# %%
q = build_wildcard_query(
                wildcard_category='gene',
                drugs=['CHEMBL:CHEMBL88'],
                disease='MONDO:0007254',
                outcome='EFO:0000714',
                outcome_name='survival_time',
                outcome_op='>',
                outcome_value=600,
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": [
#             "CHEMBL:CHEMBL88"
#           ],
#           "categories": [
#             "biolink:Drug"
#           ],
#           "constraints": []
#         },
#         "n2": {
#           "ids": [
#             "EFO:0000714"
#           ],
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "constraints": []
#         },
#         "n3": {
#           "ids": null,
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:treats"
#           ],
#           "relation": null,
#           "subject": "n1",
#           "object": "n0",
#           "constraints": []
#         },
#         "e1": {
#           "predicates": [
#             "biolink:has_phenotype"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n2",
#           "constraints": [
#             {
#               "name": "survival_time",
#               "id": "EFO:0000714",
#               "operator": ">",
#               "value": 600,
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             }
#           ]
#         },
#         "e2": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n3",
#           "object": "n0",
#           "constraints": []
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL88": {
#           "name": "CYCLOPHOSPHAMIDE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "EFO:0000714": {
#           "name": "EFO:0000714",
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000141510": {
#           "name": "TP53",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000121879": {
#           "name": "PIK3CA",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000155657": {
#           "name": "TTN",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000198626": {
#           "name": "RYR2",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000163554": {
#           "name": "SPTA1",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000181143": {
#           "name": "MUC16",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000039068": {
#           "name": "CDH1",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000198838": {
#           "name": "RYR3",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000187775": {
#           "name": "DNAH17",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000205038": {
#           "name": "PKHD1L1",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e1": {
#           "predicate": "biolink:has_phenotype",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "EFO:0000714",
#           "attributes": [
#             {
#               "attribute_type_id": "Probability of Survival",
#               "original_attribute_name": null,
#               "value": 0.2611200258889285,
#               "value_type_id": "biolink:has_confidence_level",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e2": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000141510",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.2686989657543607,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e3": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.22271729896779016,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e4": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000155657",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.09340432461338345,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e5": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000198626",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.04666245847905457,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e6": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000163554",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.04369924821094271,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e7": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000181143",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.04119915438050456,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e8": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000039068",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.033995885334095685,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e9": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000198838",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.02721849089360459,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e10": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000187775",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.02417847179896887,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e11": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000205038",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.023793175085971268,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e2"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000141510"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e3"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e4"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000155657"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e5"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000198626"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e6"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000163554"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e7"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000181143"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e8"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000039068"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e9"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000198838"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e10"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000187775"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e11"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "ENSEMBL:ENSG00000205038"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "4f74ae18-5530-4113-bffd-31a7b8681cdc"
# }

# %%
q = build_wildcard_query(
                wildcard_category='drug',
                genes=['ENSEMBL:ENSG00000121879'],
                disease='MONDO:0007254',
                outcome='EFO:0000714',
                outcome_name='survival_time',
                outcome_op='>',
                outcome_value=600,
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": [
#             "ENSEMBL:ENSG00000121879"
#           ],
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         },
#         "n2": {
#           "ids": [
#             "EFO:0000714"
#           ],
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "constraints": []
#         },
#         "n3": {
#           "ids": null,
#           "categories": [
#             "biolink:Drug"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n1",
#           "object": "n0",
#           "constraints": []
#         },
#         "e1": {
#           "predicates": [
#             "biolink:has_phenotype"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n2",
#           "constraints": [
#             {
#               "name": "survival_time",
#               "id": "EFO:0000714",
#               "operator": ">",
#               "value": 600,
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             }
#           ]
#         },
#         "e2": {
#           "predicates": [
#             "biolink:treats"
#           ],
#           "relation": null,
#           "subject": "n3",
#           "object": "n0",
#           "constraints": []
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000121879": {
#           "name": "PIK3CA",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "EFO:0000714": {
#           "name": "EFO:0000714",
#           "categories": [
#             "biolink:PhenotypicFeature"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL88": {
#           "name": "CYCLOPHOSPHAMIDE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL53463": {
#           "name": "DOXORUBICIN",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL1399": {
#           "name": "ARIMIDEX",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL83": {
#           "name": "TAMOXIFEN",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL428647": {
#           "name": "PACLITAXEL",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL92": {
#           "name": "TAXOTERE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL1201585": {
#           "name": "HERCEPTIN",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL1444": {
#           "name": "LETROZOLE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL3545252": {
#           "name": "DOCETAXEL",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL185": {
#           "name": "FLUOROURACIL",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "MONDO:0007254",
#           "attributes": []
#         },
#         "e1": {
#           "predicate": "biolink:has_phenotype",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "EFO:0000714",
#           "attributes": [
#             {
#               "attribute_type_id": "Probability of Survival",
#               "original_attribute_name": null,
#               "value": 0.11259032057434126,
#               "value_type_id": "biolink:has_confidence_level",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e2": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.5337916252156611,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e3": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL53463",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.4106491769661905,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e4": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL1399",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.37666427506286954,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e5": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL83",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.31217813081598683,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e6": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL428647",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.20850959047956938,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e7": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL92",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.15301525187592319,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e8": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL1201585",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.10292330705186716,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e9": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL1444",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.10161568125569599,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e10": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL3545252",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.0984867513196972,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e11": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL185",
#           "object": "MONDO:0007254",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.08574626287848523,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e2"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e3"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "CHEMBL:CHEMBL53463"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e4"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "CHEMBL:CHEMBL1399"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e5"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "CHEMBL:CHEMBL83"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e6"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "CHEMBL:CHEMBL428647"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e7"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "CHEMBL:CHEMBL92"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e8"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "CHEMBL:CHEMBL1201585"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e9"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "CHEMBL:CHEMBL1444"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e10"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "CHEMBL:CHEMBL3545252"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ],
#           "e1": [
#             {
#               "id": "e1"
#             }
#           ],
#           "e2": [
#             {
#               "id": "e11"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n2": [
#             {
#               "id": "EFO:0000714"
#             }
#           ],
#           "n3": [
#             {
#               "id": "CHEMBL:CHEMBL185"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "1df307e8-d40a-4023-bea7-da77c6879eca"
# }

# %%
q = build_onehop_query(
                q_object_category = 'gene',
                q_subject='CHEMBL:CHEMBL88',
                q_subject_category='drug',
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "CHEMBL:CHEMBL88"
#           ],
#           "categories": [
#             "biolink:Drug"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": null,
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:interacts_with"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n1",
#           "constraints": []
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "CHEMBL:CHEMBL88": {
#           "name": "CYCLOPHOSPHAMIDE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000141510": {
#           "name": "TP53",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000129003": {
#           "name": "VPS13C",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000155657": {
#           "name": "TTN",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000181143": {
#           "name": "MUC16",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000196632": {
#           "name": "WNK3",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000127481": {
#           "name": "UBR4",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000169855": {
#           "name": "ROBO1",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000005810": {
#           "name": "MYCBP2",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000118473": {
#           "name": "SGIP1",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000198626": {
#           "name": "RYR2",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "ENSEMBL:ENSG00000141510",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.015305072994577756,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e1": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "ENSEMBL:ENSG00000129003",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.011937490158826738,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e2": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "ENSEMBL:ENSG00000155657",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.011265657498001666,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e3": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "ENSEMBL:ENSG00000181143",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.0107876150199956,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e4": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "ENSEMBL:ENSG00000196632",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.010529562080332809,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e5": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "ENSEMBL:ENSG00000127481",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.010210255955874721,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e6": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "ENSEMBL:ENSG00000169855",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.01018732959144447,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e7": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "ENSEMBL:ENSG00000005810",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.009817363716694328,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e8": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "ENSEMBL:ENSG00000118473",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.009675879792795597,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e9": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "CHEMBL:CHEMBL88",
#           "object": "ENSEMBL:ENSG00000198626",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.008687240281302784,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000141510"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e1"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000129003"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e2"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000155657"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e3"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000181143"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e4"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000196632"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e5"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000127481"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e6"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000169855"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e7"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000005810"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e8"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000118473"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e9"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000198626"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "037c44da-8ab6-4354-9471-61250906d2e9"
# }

# %%
q = build_onehop_query(
                q_object_category = 'drug',
                q_subject='ENSEMBL:ENSG00000121879',
                q_subject_category='gene',
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "ENSEMBL:ENSG00000121879"
#           ],
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": null,
#           "categories": [
#             "biolink:Drug"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:interacts_with"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n1",
#           "constraints": []
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "ENSEMBL:ENSG00000121879": {
#           "name": "PIK3CA",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL88": {
#           "name": "CYCLOPHOSPHAMIDE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL53463": {
#           "name": "DOXORUBICIN",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL428647": {
#           "name": "PACLITAXEL",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL1444": {
#           "name": "LETROZOLE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL83": {
#           "name": "TAMOXIFEN",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL1201585": {
#           "name": "HERCEPTIN",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL1399": {
#           "name": "ARIMIDEX",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL3545252": {
#           "name": "DOCETAXEL",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL185": {
#           "name": "FLUOROURACIL",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL92": {
#           "name": "TAXOTERE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "CHEMBL:CHEMBL88",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.05949368231837154,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e1": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "CHEMBL:CHEMBL53463",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.04590498308114098,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e2": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "CHEMBL:CHEMBL428647",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.0318807802688979,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e3": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "CHEMBL:CHEMBL1444",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.01574408375532973,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e4": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "CHEMBL:CHEMBL83",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.013119213960670846,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e5": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "CHEMBL:CHEMBL1201585",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.012352855568768858,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e6": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "CHEMBL:CHEMBL1399",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.010631106847621835,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e7": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "CHEMBL:CHEMBL3545252",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.010399031530475226,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e8": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "CHEMBL:CHEMBL185",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.008411328397728759,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e9": {
#           "predicate": "biolink:interacts_with",
#           "relation": null,
#           "subject": "ENSEMBL:ENSG00000121879",
#           "object": "CHEMBL:CHEMBL92",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": 0.008223553220952182,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e1"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL53463"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e2"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL428647"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e3"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL1444"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e4"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL83"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e5"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL1201585"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e6"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL1399"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e7"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL3545252"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e8"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL185"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e9"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL92"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "3b6f520e-3c91-426c-9c59-832a5c3efb21"
# }

# %%
q = build_onehop_query(
                q_subject_category = 'disease',
                q_subject='MONDO:0007254',
                q_object_category='drug',
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": null,
#           "categories": [
#             "biolink:Drug"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:treats"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n1",
#           "constraints": []
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL88": {
#           "name": "CYCLOPHOSPHAMIDE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL53463": {
#           "name": "DOXORUBICIN",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL83": {
#           "name": "TAMOXIFEN",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL1399": {
#           "name": "ARIMIDEX",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL428647": {
#           "name": "PACLITAXEL",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL306601": {
#           "name": "TAXOL",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL1351": {
#           "name": "CARBOPLATIN",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL1201583": {
#           "name": "BEVACIZUMAB",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL92": {
#           "name": "TAXOTERE",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         },
#         "CHEMBL:CHEMBL185": {
#           "name": "FLUOROURACIL",
#           "categories": [
#             "biolink:Drug"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "CHEMBL:CHEMBL88",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.5094339622641478,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e1": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "CHEMBL:CHEMBL53463",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.37106918238993514,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e2": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "CHEMBL:CHEMBL83",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.2666666666666656,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e3": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "CHEMBL:CHEMBL1399",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.2503144654088041,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e4": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "CHEMBL:CHEMBL428647",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.15723270440251516,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e5": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "CHEMBL:CHEMBL306601",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.13459119496855307,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e6": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "CHEMBL:CHEMBL1351",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.12704402515723234,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e7": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "CHEMBL:CHEMBL1201583",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.12704402515723234,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e8": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "CHEMBL:CHEMBL92",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.1257861635220122,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e9": {
#           "predicate": "biolink:treats",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "CHEMBL:CHEMBL185",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.10691823899371031,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL88"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e1"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL53463"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e2"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL83"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e3"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL1399"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e4"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL428647"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e5"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL306601"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e6"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL1351"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e7"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL1201583"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e8"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL92"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e9"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "CHEMBL:CHEMBL185"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "838f86c7-f26e-4c2f-91d9-e5fc6863e467"
# }

# %%
q = build_onehop_query(
                q_subject_category = 'disease',
                q_subject='MONDO:0007254',
                q_object_category='gene',
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": null,
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n1",
#           "constraints": []
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000141510": {
#           "name": "TP53",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000121879": {
#           "name": "PIK3CA",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000155657": {
#           "name": "TTN",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000181143": {
#           "name": "MUC16",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000171862": {
#           "name": "PTEN",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000198626": {
#           "name": "RYR2",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000042781": {
#           "name": "USH2A",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000163554": {
#           "name": "SPTA1",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000146648": {
#           "name": "EGFR",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000168702": {
#           "name": "LRP1B",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000141510",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.38238993710691616,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e1": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000121879",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.26415094339622536,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e2": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000155657",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.23522012578616247,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e3": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000181143",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.1685534591194962,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e4": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000171862",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.12201257861635184,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e5": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000198626",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.11446540880503109,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e6": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000042781",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.09056603773584875,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e7": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000163554",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.08930817610062863,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e8": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000146648",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.08050314465408781,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e9": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000168702",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.08050314465408775,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000141510"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e1"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e2"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000155657"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e3"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000181143"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e4"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000171862"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e5"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000198626"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e6"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000042781"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e7"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000163554"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e8"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000146648"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e9"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000168702"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "04682b6b-3d80-4b06-8b17-fc49451beddb"
# }

# %%
q = build_onehop_query(
                q_subject_category = 'disease',
                q_subject='MONDO:0007254',
                q_object_category='gene',
                outcome='EFO:0000714',
                outcome_name='survival_time',
                outcome_op='>',
                outcome_value=600,
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": null,
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n1",
#           "constraints": [
#             {
#               "name": "predicate_proxy",
#               "id": "CHP:PredicateProxy",
#               "operator": "==",
#               "value": [
#                 "EFO:0000714"
#               ],
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             },
#             {
#               "name": "EFO:0000714",
#               "id": "EFO:0000714",
#               "operator": ">",
#               "value": 600,
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             }
#           ]
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000141510": {
#           "name": "TP53",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000121879": {
#           "name": "PIK3CA",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000155657": {
#           "name": "TTN",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000181143": {
#           "name": "MUC16",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000171862": {
#           "name": "PTEN",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000198626": {
#           "name": "RYR2",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000042781": {
#           "name": "USH2A",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000163554": {
#           "name": "SPTA1",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000146648": {
#           "name": "EGFR",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000168702": {
#           "name": "LRP1B",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000141510",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.5457809694793534,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e1": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000121879",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.3770197486535012,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e2": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000155657",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.33572710951526075,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e3": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000181143",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.24057450628366306,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e4": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000171862",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.17414721723518883,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e5": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000198626",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.1633752244165173,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e6": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000042781",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.12926391382405755,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e7": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000163554",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.12746858168761227,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e8": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000146648",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.11490125673249565,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e9": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000168702",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.11490125673249559,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000141510"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e1"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e2"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000155657"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e3"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000181143"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e4"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000171862"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e5"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000198626"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e6"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000042781"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e7"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000163554"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e8"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000146648"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e9"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000168702"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "8937fabe-ff56-42a8-b2af-60e775d45624"
# }

# %%
q = build_onehop_query(
                q_subject_category = 'disease',
                q_subject='MONDO:0007254',
                q_object_category='gene',
                outcome='EFO:0000714',
                outcome_name='survival_time',
                outcome_op='>',
                outcome_value=1000,
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": null,
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n1",
#           "constraints": [
#             {
#               "name": "predicate_proxy",
#               "id": "CHP:PredicateProxy",
#               "operator": "==",
#               "value": [
#                 "EFO:0000714"
#               ],
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             },
#             {
#               "name": "EFO:0000714",
#               "id": "EFO:0000714",
#               "operator": ">",
#               "value": 1000,
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             }
#           ]
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000141510": {
#           "name": "TP53",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000121879": {
#           "name": "PIK3CA",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000155657": {
#           "name": "TTN",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000181143": {
#           "name": "MUC16",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000171862": {
#           "name": "PTEN",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000198626": {
#           "name": "RYR2",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000042781": {
#           "name": "USH2A",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000163554": {
#           "name": "SPTA1",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000146648": {
#           "name": "EGFR",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         },
#         "ENSEMBL:ENSG00000168702": {
#           "name": "LRP1B",
#           "categories": [
#             "biolink:Gene"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000141510",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.37810945273631624,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e1": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000121879",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.26119402985074514,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e2": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000155657",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.23258706467661583,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e3": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000181143",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.16666666666666596,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e4": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000171862",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.12064676616915383,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e5": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000198626",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.11318407960198967,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e6": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000042781",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.08955223880596981,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e7": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000163554",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.08830845771144245,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e8": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000146648",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.07960199004975098,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         },
#         "e9": {
#           "predicate": "biolink:gene_associated_with_condition",
#           "relation": null,
#           "subject": "MONDO:0007254",
#           "object": "ENSEMBL:ENSG00000168702",
#           "attributes": [
#             {
#               "attribute_type_id": "Contribution",
#               "original_attribute_name": null,
#               "value": -0.07960199004975095,
#               "value_type_id": "biolink:has_evidence",
#               "attribute_source": null,
#               "value_url": null,
#               "description": null
#             }
#           ]
#         }
#       }
#     },
#     "results": [
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e0"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000141510"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e1"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000121879"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e2"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000155657"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e3"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000181143"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e4"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000171862"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e5"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000198626"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e6"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000042781"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e7"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000163554"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e8"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000146648"
#             }
#           ]
#         }
#       },
#       {
#         "edge_bindings": {
#           "e0": [
#             {
#               "id": "e9"
#             }
#           ]
#         },
#         "node_bindings": {
#           "n0": [
#             {
#               "id": "MONDO:0007254"
#             }
#           ],
#           "n1": [
#             {
#               "id": "ENSEMBL:ENSG00000168702"
#             }
#           ]
#         }
#       }
#     ]
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "6ede68e6-b7c2-4c23-b18b-f0e5b5248507"
# }

# %%
q = build_onehop_query(
                q_subject_category = 'disease',
                q_subject='MONDO:0007254',
                q_object_category='gene',
                #genes=['ENSEMBL:ENSG00000141510'],
                drugs = ['CHEMBL:CHEMBL88'],
                outcome='EFO:0000714',
                outcome_name='survival_time',
                outcome_op='>',
                outcome_value=600,
                trapi_version='1.1',
                )
valid, message = q.validate()
if valid:
    response = client.query(q.to_dict())
    print(json.dumps(response, indent=2))
# Out:
# {
#   "message": {
#     "query_graph": {
#       "nodes": {
#         "n0": {
#           "ids": [
#             "MONDO:0007254"
#           ],
#           "categories": [
#             "biolink:Disease"
#           ],
#           "constraints": []
#         },
#         "n1": {
#           "ids": null,
#           "categories": [
#             "biolink:Gene"
#           ],
#           "constraints": []
#         }
#       },
#       "edges": {
#         "e0": {
#           "predicates": [
#             "biolink:gene_associated_with_condition"
#           ],
#           "relation": null,
#           "subject": "n0",
#           "object": "n1",
#           "constraints": [
#             {
#               "name": "predicate_proxy",
#               "id": "CHP:PredicateProxy",
#               "operator": "==",
#               "value": [
#                 "EFO:0000714"
#               ],
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             },
#             {
#               "name": "EFO:0000714",
#               "id": "EFO:0000714",
#               "operator": ">",
#               "value": 600,
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             },
#             {
#               "name": "predicate_context",
#               "id": "CHP:PredicateContext",
#               "operator": "==",
#               "value": [
#                 "gene"
#               ],
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             },
#             {
#               "name": "gene",
#               "id": "gene",
#               "operator": "matches",
#               "value": [
#                 "ENSEMBL:ENSG00000141510"
#               ],
#               "unit_id": null,
#               "unit_name": null,
#               "not": false
#             }
#           ]
#         }
#       }
#     },
#     "knowledge_graph": {
#       "nodes": {
#         "MONDO:0007254": {
#           "name": "MONDO:0007254",
#           "categories": [
#             "biolink:Disease"
#           ],
#           "attributes": []
#         }
#       },
#       "edges": {}
#     },
#     "results": []
#   },
#   "max_results": 10,
#   "trapi_version": "1.1",
#   "biolink_version": null,
#   "pk": "9bbd6d14-4688-4c50-8c71-b165728f83b2"
# }
